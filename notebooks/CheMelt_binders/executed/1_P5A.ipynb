# %%
import numpy as np
import pandas as pd

from plotly.subplots import make_subplots

from pychemelt import Monomer
from pychemelt.utils.plotting import *

import plotly.graph_objs as go

import sys
sys.path.append('../')
from scripts import display_figure_static, set_condition_indexes_to_false

# %%
INDEX = 1
NAME = "P5A" # Name used in the manuscript

# creating a Sample object for the storage and processing of the DSF data
sample = Monomer()

# reading the data
sample.read_file(f'../../data/titer2.xlsx')

sample.set_denaturant_concentrations()

# Switch concentration 5.6 to 6 and vice versa to match the paper (@Vili Lampinen)
den_conc = sample.denaturant_concentrations_pre
idx5_6 = np.where(den_conc == 5.6)[0]
idx6 = np.where(den_conc == 6)[0]
den_conc[idx5_6], den_conc[idx6] = den_conc[idx6], den_conc[idx5_6]
sample.denaturant_concentrations_pre = den_conc
# End of switch concentrations due to manual error in the original data

# Selecting conditions
sample.set_signal(['330 nm'])#, '350 nm'])

conditions = [True]*44
# Index of the curves to be excluded from the analysis, starting from 1
outliers_or_other_data = ["1-22","24","32","35","43"] 

conditions = set_condition_indexes_to_false(conditions,outliers_or_other_data)

#using all curves except the curve without denaturant as in the paper
sample.select_conditions(conditions,normalise_to_global_max=True)
sample.set_temperature_range(35,95)

plot_config = PlotConfig()
plot_config.font_size = 24

legend_config = LegendConfig()
legend_config.color_bar_orientation = "h"
legend_config.color_bar_length = 0.6
legend_config.color_bar_x_pos = 0.7
legend_config.color_bar_y_pos = 0.9

#Plotting the selected signals against the temperature
fig = plot_unfolding(sample,plot_config=plot_config,legend_config=legend_config)
display_figure_static(fig,height=800, width=1000)

# %%
# Reducing the amount of data and preprocessing steps for a faster analysis
sample.pre_fit = False
sample.max_points = 200

sample.expand_multiple_signal()

sample.estimate_baseline_parameters(
    native_baseline_type='quadratic',
    unfolded_baseline_type='exponential',
)

# estimations of parameters
sample.estimate_derivative()
sample.guess_Tm()

# All local fit for parameter estimation
sample.fit_thermal_unfolding_local()

# Setting the number of residues of the protein for an initial estiamte of the Cp value
# We use a lower value than expected because of the hyperstability.
sample.n_residues = 60 
sample.guess_Cp()

sample.set_signal_id()

sample.compare_models(
    native_baseline_types=['linear','quadratic','exponential'],
    unfolded_baseline_types=['linear','quadratic','exponential'],
    global_model_types=['global_global_global'],
    neff=None
)

# %%
print(sample.comparison_df)
# add sample name to the comparison dataframe - first column
sample.comparison_df.insert(0, 'Sample', NAME)
# Export to csv - use sample name as filename
sample.comparison_df.to_csv(f'./comparison_tables/{INDEX}_{NAME}_comparison.csv', index=False)

#sample.params_df[:4]
# Out:
#   Native Baseline Unfolded Baseline                           Model Type  \
# 0       quadratic            linear  Global slopes and global intercepts
# 1       quadratic       exponential  Global slopes and global intercepts
# 2          linear            linear  Global slopes and global intercepts
# 3          linear       exponential  Global slopes and global intercepts
# 4          linear         quadratic  Global slopes and global intercepts
# 5     exponential         quadratic  Global slopes and global intercepts
# 6     exponential            linear  Global slopes and global intercepts
# 7       quadratic         quadratic  Global slopes and global intercepts
# 8     exponential       exponential  Global slopes and global intercepts
#
#       Tm    ΔHm   ΔCp  m-value      AIC      BIC     EBIC  Reduced χ²
# 0  173.5  230.3  1.59     5.68 -2167.80 -2012.56 -1726.25      0.3130
# 1  173.5  230.1  1.59     5.67 -2165.39 -2004.60 -1709.97      0.3132
# 2  169.8  189.2  1.35     4.54 -1885.34 -1735.64 -1457.74      0.3636
# 3  169.7  189.3  1.35     4.55 -1883.30 -1728.06 -1441.76      0.3638
# 4  173.8  129.3  0.82     3.29 -1825.60 -1681.45 -1412.01      0.3755
# 5  171.5  122.0  0.79     3.06 -1688.21 -1527.42 -1232.80      0.4031
# 6  175.3  119.9  0.78     3.01 -1614.02 -1458.78 -1172.48      0.4195
# 7  194.0   43.6  0.35     0.50   737.43   898.21  1192.84      1.4549
# 8  224.9   38.7  0.26     0.50  1212.68  1373.46  1668.09      1.8709

# %%
sel_id = (
    (sample.comparison_df["Native Baseline"] == "quadratic") &
    (sample.comparison_df["Unfolded Baseline"] == "linear")
)
sel_id = np.where(sel_id)[0][0]
# Replace sample with the best model - lowest EBIC with physically meaningful parameters
best_model = sample.fit_objects[sel_id]
# Estimate error using leave_one_out cross validation
best_model.leave_one_out_cross_validation()

# Save the leave one out results to a csv file
best_model.loo_df.to_csv(f'./leave_one_out_results/{INDEX}_{NAME}_loo.csv', index=False)

print(best_model.params_df)
# Out:
#                                   Parameter       Value  Relative error (%)  \
# 0                                   Tm (°C)  173.504816            0.261709
# 1                            ΔHm (kcal/mol)  230.294673            3.680643
# 2                         ΔCp (kcal/mol/°C)    1.593086            4.741128
# 3                      m-value (kcal/mol/M)    5.676110            3.084571
# 4                 intercept_native - 330 nm  115.382871            3.054412
# 5               intercept_unfolded - 330 nm  100.325316            4.470920
# 6                slope_term_native - 330 nm   -0.337821            1.429548
# 7              slope_term_unfolded - 330 nm   -0.370221            2.125659
# 8     denaturant_slope_term_native - 330 nm   -4.963231           12.730444
# 9   denaturant_slope_term_unfolded - 330 nm   -4.715424           15.936642
# 10           quadratic_term_native - 330 nm   -0.001189            6.131656
# 11            Scale factor - 4.0 (M). ID: 0    0.879956            1.151415
# 12            Scale factor - 4.4 (M). ID: 1    0.922768            0.863293
# 13            Scale factor - 4.6 (M). ID: 2    0.928705            0.716417
# 14            Scale factor - 4.8 (M). ID: 3    0.967936            0.570254
# 15            Scale factor - 5.0 (M). ID: 4    0.956376            0.430221
# 16            Scale factor - 5.2 (M). ID: 5    0.954729            0.300322
# 17            Scale factor - 5.4 (M). ID: 6    0.964287            0.186537
# 18            Scale factor - 6.0 (M). ID: 7    1.095238            0.517149
# 19            Scale factor - 5.6 (M). ID: 8    1.083766            0.108112
# 20            Scale factor - 4.0 (M). ID: 9    0.920035            1.151169
# 21           Scale factor - 4.4 (M). ID: 10    1.053792            0.862509
# 22           Scale factor - 4.6 (M). ID: 11    0.941984            0.716301
# 23           Scale factor - 4.8 (M). ID: 12    1.076972            0.569326
# 24           Scale factor - 5.0 (M). ID: 13    1.014790            0.429463
# 25           Scale factor - 5.2 (M). ID: 14    1.036669            0.298782
# 26           Scale factor - 5.4 (M). ID: 15    1.017022            0.184825
# 27           Scale factor - 6.0 (M). ID: 16    0.965370            0.519079
#
#     Fitting low Bound  Fitting high Bound
# 0           90.590837          212.586135
# 1           10.000000          500.000000
# 2            0.100000            5.000000
# 3            0.500000            9.000000
# 4            0.707963         7079.631250
# 5            0.834902         8349.020722
# 6         -100.000000          100.000000
# 7        -1254.003417          100.000000
# 8           -4.963231          372.691966
# 9         -283.102579            4.972190
# 10         -10.000000           10.000000
# 11           0.588200            1.700000
# 12           0.588200            1.700000
# 13           0.588200            1.700000
# 14           0.588200            1.700000
# 15           0.588200            1.700000
# 16           0.588200            1.700000
# 17           0.588200            1.700000
# 18           0.588200            1.700000
# 19           0.588200            1.700000
# 20           0.588200            1.700000
# 21           0.588200            1.700000
# 22           0.588200            1.700000
# 23           0.588200            1.700000
# 24           0.588200            1.700000
# 25           0.588200            1.700000
# 26           0.588200            1.700000
# 27           0.588200            1.700000
# /Users/oburastero/myenv/lib/python3.12/site-packages/lmfit/minimizer.py:827: RuntimeWarning: invalid value encountered in sqrt
#   np.sqrt(self.result.covar[jvar, jvar])))
# /Users/oburastero/myenv/lib/python3.12/site-packages/lmfit/minimizer.py:819: RuntimeWarning: invalid value encountered in sqrt
#   par.stderr = float(np.sqrt(self.result.covar[ivar, ivar]))

# %%
fig = plot_unfolding(best_model,plot_config=plot_config,legend_config=legend_config)
display_figure_static(fig,height=800, width=1000)

# %%
# Plot the curves taking into account the effect of the scaling factor
fig = plot_unfolding(best_model,plot_config=plot_config,legend_config=legend_config,use_scaled_data=True)
# save figure
#fig.write_image(f"./figures/{INDEX}_{NAME}_unfolding_curves_fitted_scaled.png")

display_figure_static(fig,height=800, width=1000)

# %%
"""
Save a python object as a pickle file for future plotting without need to re-fit
Required attributes are:
    - global_fit_params
    - denaturant_concentrations
    - nr_signals
    - signal_names
    - nr_den
    - temp_lst_expanded
    - predicted_lst_multiple_scaled
    - max_points
    - signal_lst_multiple_scaled
    - oligomeric
    - predicted_deriv_lst_multiple
"""

import pickle

class Test:
    pass

with open(f'./py_objects/{INDEX}_{NAME}_best_model.pkl', 'wb') as f:
    t = Test()
    t.global_fit_params = best_model.global_fit_params
    t.denaturant_concentrations = best_model.denaturant_concentrations
    t.nr_signals = best_model.nr_signals
    t.signal_names = best_model.signal_names
    t.nr_den = best_model.nr_den
    t.temp_lst_expanded = best_model.temp_lst_expanded
    t.predicted_lst_multiple_scaled = best_model.predicted_lst_multiple_scaled
    t.max_points = best_model.max_points
    t.signal_lst_multiple_scaled = best_model.signal_lst_multiple_scaled
    t.oligomeric = best_model.oligomeric
    t.predicted_deriv_lst_multiple = best_model.predicted_deriv_lst_multiple

    # dump it
    pickle.dump(t, f)
